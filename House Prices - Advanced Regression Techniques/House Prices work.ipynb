# %%
# load and show training data from train.csv
import pandas as pd
import numpy as np
df = pd.read_csv('train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# load and show test data from test.csv
df_test = pd.read_csv('test.csv')
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
# create target variable
target = df["SalePrice"]

# %%
# prepare data for training
df = df.drop(["SalePrice"], axis=1)
df = df.drop(["Id"], axis=1)
df_test = df_test.drop(["Id"], axis=1)

# %%
# create pipline for data preparation
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# get numerical and categorical columns
numerical_columns = df.select_dtypes(include=["int64", "float64"]).columns
categorical_columns = df.select_dtypes(include=[object]).columns

# create pipeline for numerical columns
numerical_pipeline = Pipeline([
    ('imputer', SimpleImputer(missing_values=None, fill_value=0, strategy='constant')),
    ('std_scaler', StandardScaler())
])

# create pipeline for categorical columns
categorical_pipeline = Pipeline([
    ('imputer', SimpleImputer(missing_values=None, fill_value='missing', strategy='constant')),
    ('onehot', OneHotEncoder())
])

# create full pipeline
full_pipeline = ColumnTransformer([
    ('num', numerical_pipeline, numerical_columns),
    ('cat', categorical_pipeline, categorical_columns)
])

# %%
# prepare data for training
X = full_pipeline.fit_transform(df)
X_test = full_pipeline.transform(df_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 # prepare data for training
# ----> 2 X = full_pipeline.fit_transform(df)
#       3 X_test = full_pipeline.transform(df_test)
#
# File c:\Users\Dustin_2\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\compose\_column_transformer.py:690, in ColumnTransformer.fit_transform(self, X, y)
#     687 self._validate_column_callables(X)
#     688 self._validate_remainder(X)
# --> 690 result = self._fit_transform(X, y, _fit_transform_one)
#     692 if not result:
#     693     self._update_fitted_transformers([])
#
# File c:\Users\Dustin_2\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\compose\_column_transformer.py:621, in ColumnTransformer._fit_transform(self, X, y, func, fitted, column_as_strings)
#     615 transformers = list(
#     616     self._iter(
# ...
